# %% [markdown]
# # **Written by**: Abdullah Riaz
#
# ## **Date**: 29.04.2024
#
# ## **Email**: abdullah.riaz.ar.98@gmail.com

# %%
# Importing libraries
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ##### First we load the dataset

# %%
# loading and viewing data
df = pd.read_csv('CO2_emission.csv')
df.head()
# Out:
#    Model_Year   Make              Model Vehicle_Class  Engine_Size  Cylinders  \
# 0        2021  Acura                ILX       Compact          2.4          4
# 1        2021  Acura                NSX    Two-seater          3.5          6
# 2        2021  Acura         RDX SH-AWD    SUV: Small          2.0          4
# 3        2021  Acura  RDX SH-AWD A-SPEC    SUV: Small          2.0          4
# 4        2021  Acura         TLX SH-AWD       Compact          2.0          4
#
#   Transmission  Fuel_Consumption_in_City(L/100 km)  \
# 0          AM8                                 9.9
# 1          AM9                                11.1
# 2         AS10                                11.0
# 3         AS10                                11.3
# 4         AS10                                11.2
#
#    Fuel_Consumption_in_City_Hwy(L/100 km)  Fuel_Consumption_comb(L/100km)  \
# 0                                     7.0                             8.6
# ...

# %% [markdown]
# ##### Statics of dataset:

# %%
# Summary
df.describe()
# Out:
#        Model_Year  Engine_Size   Cylinders  \
# count       935.0   935.000000  935.000000
# mean       2021.0     3.214866    5.716578
# std           0.0     1.388513    1.977359
# min        2021.0     1.000000    3.000000
# 25%        2021.0     2.000000    4.000000
# 50%        2021.0     3.000000    6.000000
# 75%        2021.0     4.000000    8.000000
# max        2021.0     8.000000   16.000000
#
#        Fuel_Consumption_in_City(L/100 km)  \
# count                          935.000000
# mean                            12.498610
# std                              3.487271
# min                              4.000000
# 25%                             10.100000
# 50%                             12.000000
# 75%                             14.800000
# max                             30.300000
#
#        Fuel_Consumption_in_City_Hwy(L/100 km)  Fuel_Consumption_comb(L/100km)  \
# count                              935.000000                      935.000000
# ...

# %% [markdown]
# ##### Getting informstion about type of data stored in dataset

# %%
# Column names
df.columns
# Out:
# Index(['Model_Year', 'Make', 'Model', 'Vehicle_Class', 'Engine_Size',
#        'Cylinders', 'Transmission', 'Fuel_Consumption_in_City(L/100 km)',
#        'Fuel_Consumption_in_City_Hwy(L/100 km)',
#        'Fuel_Consumption_comb(L/100km)', 'CO2_Emissions', 'Smog_Level'],
#       dtype='object')

# %% [markdown]
# ##### Knowing the total number of Columns and Rows of dataset

# %%
df.shape
# Out:
# (935, 12)

# %% [markdown]
# #### Following is the code to know about type of data stored across each column and number non zero values in each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Model_Year                              935 non-null    int64
#  1   Make                                    935 non-null    object
#  2   Model                                   935 non-null    object
#  3   Vehicle_Class                           935 non-null    object
#  4   Engine_Size                             935 non-null    float64
#  5   Cylinders                               935 non-null    int64
#  6   Transmission                            935 non-null    object
#  7   Fuel_Consumption_in_City(L/100 km)      935 non-null    float64
#  8   Fuel_Consumption_in_City_Hwy(L/100 km)  935 non-null    float64
#  9   Fuel_Consumption_comb(L/100km)          935 non-null    float64
# ...

# %%
df.dtypes
# Out:
# Model_Year                                  int64
# Make                                       object
# Model                                      object
# Vehicle_Class                              object
# Engine_Size                               float64
# Cylinders                                   int64
# Transmission                               object
# Fuel_Consumption_in_City(L/100 km)        float64
# Fuel_Consumption_in_City_Hwy(L/100 km)    float64
# Fuel_Consumption_comb(L/100km)            float64
# CO2_Emissions                               int64
# Smog_Level                                  int64
# dtype: object

# %% [markdown]
# ##### Checking the number of null values across the dataframe

# %%
df.isnull().sum() / len(df) * 100
# Out:
# Model_Year                                0.0
# Make                                      0.0
# Model                                     0.0
# Vehicle_Class                             0.0
# Engine_Size                               0.0
# Cylinders                                 0.0
# Transmission                              0.0
# Fuel_Consumption_in_City(L/100 km)        0.0
# Fuel_Consumption_in_City_Hwy(L/100 km)    0.0
# Fuel_Consumption_comb(L/100km)            0.0
# CO2_Emissions                             0.0
# Smog_Level                                0.0
# dtype: float64

# %% [markdown]
# ##### Visualizing data

# %%
sns.pairplot(df)
# Out:
# c:\Users\abdul\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\abdul\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\abdul\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.lmplot(x='Fuel_Consumption_in_City(L/100 km)', y='CO2_Emissions', data=df, hue='Make')

# %% [markdown]
# ##### Checking Mileage by Brand

# %%
plt.figure(figsize=(25, 10))  # Adjust width and height as needed

# Create the bar plot
sns.barplot(data=df, x='Model_Year', y='Fuel_Consumption_in_City(L/100 km)', hue='Make', linewidth=5)

# Show the plot
plt.show()

# %% [markdown]
# ##### Checking CO2 Emission by Brand

# %%
plt.figure(figsize=(25, 10))  # Adjust width and height as needed

sns.barplot(data=df, x='Model_Year', y='CO2_Emissions', hue='Make', linewidth=5)

plt.show()
